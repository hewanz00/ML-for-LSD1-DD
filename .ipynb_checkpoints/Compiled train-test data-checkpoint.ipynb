# %% [markdown]
# Development of the new ML model with larger compiled train/ test data

# %%
#Dataset compilation and cleansing done by hand. Cleansing found in './datasets/LSD1 inhibitors new dataset.csv'

# %% [markdown]
# data construction

# %%
import json
import numpy as np
import pandas as pd
import re
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import DataStructs

from utils3 import save_dataset, get_parameters
from rdkit_utils import smiles_dataset

dataset = pd.read_csv('./datasets/compiled dataset.csv')


# change the parameters in .json file
dic = get_parameters(path = './settings/fp_settings.json', print_dict = False)

x = smiles_dataset(dataset_df = dataset, smiles_loc = 'SMILES',
                   fp_radius = dic.get("fp_radius"), fp_bits = dic.get("fp_bits"))

y = dataset['Calculated pChEMBL']

# change file_name to save as different datasets
save_dataset(x, file_name = ("3_512_x_main3"), idx = False)
save_dataset(y, file_name = ("3_512_y_main3"), idx = False)
# Out:
# json file path is: ./settings/fp_settings.json
# Current path is: C:\Users\hewan\Downloads\ml-lsd1\datasets
# Path already existed.
# Dataset saved successfully.
# Current path is: C:\Users\hewan\Downloads\ml-lsd1\datasets
# Path already existed.
# Dataset saved successfully.

# %% [markdown]
# Algortihm Hyperparameter Optimisation

# %%
import numpy as np
import pandas as pd
from utils3 import pipeline_optim

np.random.seed(42)
dataset = pd.read_csv('./datasets/3_512_x_main3.csv')
target = pd.read_csv('./datasets/3_512_y_main3.csv')

# generate optimization hyperparameters of algorithms

knn = pipeline_optim(dataset, target, random_seeds = 42, mode = 'knn')
ridge = pipeline_optim(dataset, target, random_seeds = 42, mode = 'ridge')
lasso = pipeline_optim(dataset, target, random_seeds = 42, mode = 'lasso')
elastic = pipeline_optim(dataset, target, random_seeds = 42, mode = 'elastic')
gb = pipeline_optim(dataset, target, random_seeds = 42, mode = 'gradientboosting')
rf = pipeline_optim(dataset, target, random_seeds = 42, mode = 'rf')
ada = pipeline_optim(dataset, target, random_seeds = 42, mode = 'adaboost')
extra = pipeline_optim(dataset, target, random_seeds = 42, mode = 'extratrees')
dt = pipeline_optim(dataset, target, random_seeds = 42, mode = 'dt')
svr = pipeline_optim(dataset, target, random_seeds = 42, mode = 'svr')
# Out:
# The best hyperparameters: KNeighborsRegressor(algorithm='brute', leaf_size=20, n_neighbors=3, p=1,
#                     weights='distance')
# Time for optimization: 279.206001 seconds
# *********************************
# The best hyperparameters: Ridge()
# Time for optimization: 4.588725 seconds
# *********************************
# The best hyperparameters: Lasso(alpha=0.001, max_iter=100000, selection='random')
# Time for optimization: 1.647948 seconds
# *********************************
# The best hyperparameters: ElasticNet(alpha=0.01, l1_ratio=0.2, max_iter=100000)
# Time for optimization: 10.578517 seconds
# *********************************
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'squared_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 441, in fit
#     self._check_params()
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\ensemble\_gb.py", line 236, in _check_params
#     raise ValueError("Loss '{0:s}' not supported. ".format(self.loss))
# ValueError: Loss 'absolute_error' not supported.
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
# ...
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\hewan\anaconda3\envs\ml-lsd1\lib\site-packages\sklearn\tree\_classes.py", line 336, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'squared_error'
#
#   FitFailedWarning)
# The best hyperparameters: DecisionTreeRegressor(criterion='friedman_mse', min_samples_split=8)
# Time for optimization: 1.812573 seconds
# *********************************
# The best hyperparameters: SVR(C=10)
# Time for optimization: 5823.021687 seconds
# *********************************

# %% [markdown]
# Model Fitting

# %%
import numpy as np
import pandas as pd

from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.linear_model import Lasso, Ridge, LinearRegression, ElasticNet

from utils3 import fit_result, get_parameters

np.random.seed(42)

dataset = pd.read_csv('./datasets/3_512_x_main3.csv')
target = pd.read_csv('./datasets/3_512_y_main3.csv')
x_values = dataset.values
y_values = target.values.ravel()


# import fitting_settings.json to retrive optimization hyperparameters for
# raidus = 3, fingerprint bits = 512 dataset
dic = get_parameters(path = './settings/fitting_settings.json', print_dict = False)

fit_result(x_values, y_values, KNeighborsRegressor(algorithm='ball_tree', leaf_size=20, n_neighbors=6, p=1, weights='distance'), random_seeds_start = dic.get("random_seeds_start"), random_seeds_stop = dic.get("random_seeds_stop"), random_seeds_step = dic.get("random_seeds_step"))
fit_result(x_values, y_values, Ridge(), random_seeds_start = dic.get("random_seeds_start"), random_seeds_stop = dic.get("random_seeds_stop"), random_seeds_step = dic.get("random_seeds_step"))
fit_result(x_values, y_values, Lasso(alpha=0.01, max_iter=100000), random_seeds_start = dic.get("random_seeds_start"), random_seeds_stop = dic.get("random_seeds_stop"), random_seeds_step = dic.get("random_seeds_step"))
fit_result(x_values, y_values, ElasticNet(alpha=0.01, l1_ratio=0.2, max_iter=100000), random_seeds_start = dic.get("random_seeds_start"), random_seeds_stop = dic.get("random_seeds_stop"), random_seeds_step = dic.get("random_seeds_step"))
fit_result(x_values, y_values, GradientBoostingRegressor(criterion='mse', loss='huber', min_samples_split=3), random_seeds_start = dic.get("random_seeds_start"), random_seeds_stop = dic.get("random_seeds_stop"), random_seeds_step = dic.get("random_seeds_step"))
fit_result(x_values, y_values, RandomForestRegressor(bootstrap=False, max_features='sqrt', min_samples_split=4), random_seeds_start = dic.get("random_seeds_start"), random_seeds_stop = dic.get("random_seeds_stop"), random_seeds_step = dic.get("random_seeds_step"))
fit_result(x_values, y_values, AdaBoostRegressor(learning_rate=1), random_seeds_start = dic.get("random_seeds_start"), random_seeds_stop = dic.get("random_seeds_stop"), random_seeds_step = dic.get("random_seeds_step"))
fit_result(x_values, y_values, ExtraTreesRegressor(), random_seeds_start = dic.get("random_seeds_start"), random_seeds_stop = dic.get("random_seeds_stop"), random_seeds_step = dic.get("random_seeds_step"))
fit_result(x_values, y_values, DecisionTreeRegressor(criterion='friedman_mse', min_samples_split=9), random_seeds_start = dic.get("random_seeds_start"), random_seeds_stop = dic.get("random_seeds_stop"), random_seeds_step = dic.get("random_seeds_step"))
fit_result(x_values, y_values, SVR(C=10), random_seeds_start = dic.get("random_seeds_start"), random_seeds_stop = dic.get("random_seeds_stop"), random_seeds_step = dic.get("random_seeds_step"))
# Out:
# json file path is: ./settings/fitting_settings.json
# The average train score of all random states:0.996
# The average test score of all random states:0.715
# The average train rmse of all random states:0.076
# The average test rmse of all random states:0.647
# ---------------------------------
# The train score std: 0.0011
# The test score std: 0.0363
# The train rmse std: 0.0107
# The test rmse std: 0.0321
# ---------------------------------
# Time for fitting: 46.597638 seconds
# *********************************
# The average train score of all random states:0.898
# The average test score of all random states:0.548
# The average train rmse of all random states:0.393
# The average test rmse of all random states:0.816
# ---------------------------------
# The train score std: 0.0045
# The test score std: 0.0448
# The train rmse std: 0.0077
# The test rmse std: 0.0384
# ---------------------------------
# Time for fitting: 27.495078 seconds
# *********************************
# The average train score of all random states:0.699
# The average test score of all random states:0.596
# The average train rmse of all random states:0.677
# The average test rmse of all random states:0.771
# ---------------------------------
# The train score std: 0.0086
# The test score std: 0.0402
# The train rmse std: 0.0071
# The test rmse std: 0.0404
# ---------------------------------
# Time for fitting: 1.021565 seconds
# *********************************
# The average train score of all random states:0.819
# The average test score of all random states:0.664
# The average train rmse of all random states:0.525
# The average test rmse of all random states:0.703
# ---------------------------------
# The train score std: 0.0051
# The test score std: 0.0379
# The train rmse std: 0.0058
# The test rmse std: 0.0376
# ---------------------------------
# Time for fitting: 3.012117 seconds
# *********************************
# The average train score of all random states:0.828
# The average test score of all random states:0.665
# The average train rmse of all random states:0.511
# The average test rmse of all random states:0.702
# ---------------------------------
# The train score std: 0.0052
# The test score std: 0.0371
# The train rmse std: 0.0068
# The test rmse std: 0.0393
# ---------------------------------
# Time for fitting: 39.157665 seconds
# *********************************
# The average train score of all random states:0.985
# The average test score of all random states:0.732
# The average train rmse of all random states:0.152
# The average test rmse of all random states:0.629
# ---------------------------------
# The train score std: 0.0011
# The test score std: 0.0255
# The train rmse std: 0.0048
# The test rmse std: 0.0311
# ---------------------------------
# Time for fitting: 15.705116 seconds
# *********************************
# The average train score of all random states:0.583
# The average test score of all random states:0.510
# The average train rmse of all random states:0.796
# The average test rmse of all random states:0.850
# ---------------------------------
# The train score std: 0.0196
# The test score std: 0.0322
# The train rmse std: 0.0167
# The test rmse std: 0.0339
# ---------------------------------
# Time for fitting: 29.843493 seconds
# *********************************
# The average train score of all random states:0.996
# The average test score of all random states:0.522
# The average train rmse of all random states:0.076
# The average test rmse of all random states:0.838
# ---------------------------------
# The train score std: 0.0011
# The test score std: 0.0723
# The train rmse std: 0.0107
# The test rmse std: 0.0667
# ---------------------------------
# Time for fitting: 141.577641 seconds
# *********************************
# The average train score of all random states:0.947
# The average test score of all random states:0.499
# The average train rmse of all random states:0.283
# The average test rmse of all random states:0.858
# ---------------------------------
# The train score std: 0.0051
# The test score std: 0.0709
# The train rmse std: 0.0132
# The test rmse std: 0.0622
# ---------------------------------
# Time for fitting: 1.645358 seconds
# *********************************
# The average train score of all random states:0.989
# The average test score of all random states:0.744
# The average train rmse of all random states:0.131
# The average test rmse of all random states:0.614
# ---------------------------------
# The train score std: 0.0014
# The test score std: 0.0262
# The train rmse std: 0.0078
# The test rmse std: 0.0308
# ---------------------------------
# Time for fitting: 52.369305 seconds
# *********************************

# %% [markdown]
# Plot Learning Curves

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.linear_model import Lasso, Ridge, LinearRegression, ElasticNet
import utils3
from utils3 import plot_multi_learning_curves

np.random.seed(42)
dataset = pd.read_csv('./datasets/3_512_x_main3.csv')
target = pd.read_csv('./datasets/3_512_y_main3.csv')
x_values = dataset.values
y_values = target.values.ravel()

estimator1 = SVR(C=10)
estimator2 = RandomForestRegressor(bootstrap=False, max_features='sqrt', min_samples_split=4)
estimator3 = DecisionTreeRegressor(criterion='friedman_mse', min_samples_split=9)

plot_multi_learning_curves(x_values, y_values, estimator1, estimator2, estimator3,
                           random_seed = 42, testsize = 0.2, mode = 'r2', autosave = 'y', interval = None)
# Out:
# Current path is: C:\Users\hewan\Downloads\ml-lsd1\figures
# Path already existed.
# Figure saved successfully.

# %% [markdown]
# tSNE

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from PIL import Image

from sklearn.manifold import TSNE


np.random.seed(42)

path = os.path.join(os.getcwd(), 'figures')
print('Current path is:', path)

if os.path.exists(path) == True:
    pass
    print('Path already existed.')
else:
    os.mkdir(path)
    print('Path created.')

x_values = pd.read_csv('./datasets/3_512_x_main3.csv').values
y_values = pd.read_csv('./datasets/3_512_y_main3.csv').values.ravel()
tsne_descriptors = TSNE(n_components=2, random_state = 42)
x_tsne = tsne_descriptors.fit_transform(x_values)

# manually added new/old labels on ./datasets/3_512_y_main3.csv
tsne_df=pd.DataFrame(np.transpose(np.array([x_tsne[:, 0], x_tsne[:, 1]])), columns=["T1", "T2"])
tsne_df["old/new"]= dataset["old/new"]

tsne_df_old = tsne_df[tsne_df["old/new"] =="old"]
tsne_df_new = tsne_df[tsne_df["old/new"] =="new"]

# draw tsne
cm = plt.cm.get_cmap('RdYlBu')
plt.figure(figsize=(16, 8))
plt.xticks(size = 22)
plt.yticks(size = 22)
plt.xlabel('t-SNE Reduced Dimension 1',fontproperties = 'Times New Roman', size = 24)
plt.ylabel('t-SNE Reduced Dimension 2',fontproperties = 'Times New Roman', size = 24)
plt.scatter(tsne_df_old["T1"], tsne_df_old["T2"],color="red",vmin= 3, vmax= 9, s= 20)
plt.scatter(tsne_df_new["T1"], tsne_df_new["T2"],color="blue",vmin= 3, vmax= 9, s= 20)

plt.text(58, -70, "pChEMBL Value", fontproperties = 'Times New Roman', size = 18)
plt.savefig("figures/TSNE3.png", bbox_inches='tight', pad_inches= 0)

tsne_image = Image.open('figures/TSNE3.png')
tsne_image.show()
# Out:
# Current path is: C:\Users\hewan\Downloads\ml-lsd1\figures
# Path already existed.

# %% [markdown]
# Neural Network

# %%
import torch
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.model_selection import train_test_split
from torchmetrics import functional
from torch.autograd import Variable
import matplotlib.pyplot as plt
import random

from nn_utils import weight_reset, result_average_NN

dataset = pd.read_csv('./datasets/3_512_x_main3.csv')
target = pd.read_csv('./datasets/3_512_y_main3.csv')

class predict_model(nn.Module):
    def __init__(self, x_size, hidden1_size, hidden2_size, y_size):
        super(predict_model, self).__init__()
        self.hidden1 = nn.Linear(x_size, hidden1_size)
        self.batch1 = nn.BatchNorm1d(hidden1_size)
        self.hidden2 = nn.Linear(hidden1_size, hidden2_size)
        self.batch2 = nn.BatchNorm1d(hidden2_size)
        self.predict = nn.Linear(hidden2_size, y_size)
    def forward(self, input):
        result = self.hidden1(input)
        result = self.batch1(result)
        result = F.leaky_relu(result)
        result = self.hidden2(result)
        result = self.batch2(result)
        result = F.leaky_relu(result)
        result = self.predict(result)

# %% [markdown]
# Deployment of Screening Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import os
from sklearn.svm import SVR
import joblib

import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem

from rdkit_utils import smiles_dataset
from utils3 import save_dataset, get_parameters

model_load = joblib.load('./model_test.pkl')
database = pd.read_csv('./screening_base/in-vitro_zinc/in-vitro.csv')

dic = get_parameters(path = './settings/fp_settings.json', print_dict = False)
database_fp = smiles_dataset(dataset_df = database, smiles_loc = 'smiles',
                   fp_radius = dic.get("fp_radius"), fp_bits = dic.get("fp_bits"))

save_dataset(database_fp, path = './datasets/screen_results/in-vitro_zinc/', file_name = 'in-vitro_bits', idx = False)
# Out:
# json file path is: ./settings/fp_settings.json
# Current path is: ./datasets/screen_results/in-vitro_zinc/
# Path already existed.
# Dataset saved successfully.

# %% [markdown]
# Deployment of model for virtual screening

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import os
from sklearn.svm import SVR
import joblib

import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem

from rdkit_utils import smiles_dataset
from utils3 import save_dataset


model_load = joblib.load('./model_test.pkl')
database = pd.read_csv('./screening_base/in-vitro_zinc/in-vitro.csv')
screen_database = pd.read_csv('./datasets/screen_results/in-vitro_zinc/in-vitro_bits.csv')

screen_result = model_load.predict(screen_database)
screen_result_fp = pd.DataFrame({'Predictive Results': screen_result})
database_result = pd.concat([database, screen_result_fp], axis = 1)

threshold_7 = database_result[database_result['Predictive Results'] > 7]

original_dataset = pd.read_csv('./datasets/compiled dataset.csv')
de_threshold_7 = threshold_7
for smile in original_dataset['SMILES']:
    for new_structure in threshold_7['smiles']:
        if smile == new_structure:
            index = threshold_7[threshold_7['smiles'] == smile].index[0]
            print('overlap found at position: {:01d}'.format(index))
            de_threshold_7 = de_threshold_7.drop(index = index, axis = 0)
        else:
            pass

save_dataset(threshold_7, path = './datasets/screen_results/in-vitro_zinc/', file_name = 'threshold_7_compiled2', idx = False)
save_dataset(de_threshold_7, path = './datasets/screen_results/in-vitro_zinc/', file_name = 'de_threshold_7_compiled2', idx = False)
# Out:
# overlap found at position: 253636
# overlap found at position: 297437
# overlap found at position: 32529
# overlap found at position: 64469
# overlap found at position: 92462
# overlap found at position: 291060
# Current path is: ./datasets/screen_results/in-vitro_zinc/
# Path already existed.
# Dataset saved successfully.
# Current path is: ./datasets/screen_results/in-vitro_zinc/
# Path already existed.
# Dataset saved successfully.

# %% [markdown]
# rest of code is utils -- not needed to run here
